# %% [markdown]
# # BTVN Assignment 8: Scene Classification
#
# - Sử dụng các mô hình phân loại (KNN, Decision Tree, SVM) để phân loại các ảnh viễn thám trên bộ CSDL http://vision.ucmerced.edu/datasets/landuse.html
# - Cài đặt gist ở https://github.com/tuttieee/lear-gist-python

# %% [markdown]
# # Y/c thử với cả dữ liệu không PCA và PCA, So sánh kết quả

# %%
import os
import gist
import cv2
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
##########Sử dụng Gist + PCA###############
cnt = -1
features = []
labels = []

path = 'UCMerced_LandUse/Images/'
for c in os.listdir(path):
    cnt += 1
    for file_name in os.listdir(os.path.join(path,c)):
        file_path = os.path.join(path,c,file_name)
        img = cv2.imread(file_path)
        labels.append(cnt)
        features.append(gist.extract(img))

########Your code here############# 

scaled_data = None
#####################################
pca = PCA()
pca.fit(scaled_data)
print(pca.explained_variance_ratio_)

pca1 = PCA(n_components=43)
data1 = pca1.fit_transform(scaled_data)

X_pan = pd.DataFrame(data1)
X_pan1 = pd.DataFrame(features)
X_pan["labels"] = labels
X_pan1["labels"] = labels
"""
UCMerced_LandUse.csv: dataset without PCA
UCMerced_LandUse_PCA.csv: dataset with PCA
"""
X_pan.to_csv("UCMerced_LandUse.csv")
X_pan1.to_csv("UCMerced_LandUse_PCA.csv")

'''
labels:
    0:agricultural(100)
    1:airplane(100)
    2:baseballdiamond(100)
    3:beach(100)
    4:buildings(100)
    5:chaparral(100)
    6:denseresidential(100)
    7:forest(100)
    8:freeway(100)
    9:golfcourse(100)
    10:harbor(100)
    11:intersection(100)
    12:mediumresidential(100)
    13:mobilehomepark(100)
    14:overpass(100)
    15:parkinglot(100)
    16:river(100)
    17:runway(100)
    18:sparseresidential(100)
    19:storagetanks(100)
    20:tenniscourt(100)
'''
# Out:
# [3.57766423e-01 1.09789096e-01 6.28109132e-02 5.35507627e-02
#  4.67488243e-02 3.93381550e-02 2.43373228e-02 1.74080839e-02
#  1.54161054e-02 1.49580667e-02 1.41700882e-02 1.30048213e-02
#  1.19843794e-02 1.08704602e-02 9.46056624e-03 7.29631297e-03
#  6.95780596e-03 6.76318341e-03 6.41323622e-03 6.07538302e-03
#  5.84974435e-03 5.48918506e-03 5.16129058e-03 5.10019327e-03
#  5.02516462e-03 4.62301002e-03 4.30501710e-03 3.78604279e-03
#  3.63458851e-03 3.41057305e-03 3.32559697e-03 3.21292089e-03
#  3.11659085e-03 2.84954546e-03 2.75034879e-03 2.62123696e-03
#  2.56347294e-03 2.43297940e-03 2.40339991e-03 2.26092797e-03
#  2.18208042e-03 2.13094875e-03 2.08599061e-03 2.01423875e-03
#  1.96400022e-03 1.91408603e-03 1.71517899e-03 1.64510611e-03
#  1.58601220e-03 1.51036403e-03 1.46496881e-03 1.45291557e-03
#  1.43338304e-03 1.38148675e-03 1.35847727e-03 1.29105514e-03
#  1.26311359e-03 1.25562157e-03 1.20241800e-03 1.18319050e-03
# ...

# %%
######Your code here###############
data = None
###################################
# Out:
#       Unnamed: 0          0         1         2          3          4  \
# 1489        1489 -14.205454 -2.319854 -3.017632  12.425863   3.098608
# 650          650  -6.069100 -5.376269 -4.544902  -2.887918  -3.342614
# 801          801  -4.728053 -8.316286  0.496340 -26.268229 -11.953861
# 1534        1534   7.976685 -3.099465  2.683954  -6.152035  -6.277931
# 2086        2086  -8.360815  1.883378 -3.865789  -4.442186   0.537031
#
#              5         6         7         8  ...        34        35  \
# 1489 -1.440606 -3.837777  0.733801  3.816857  ... -2.059969  2.974467
# 650  -2.224633 -3.632119  3.775396 -3.289899  ...  0.544020  0.589850
# 801  -2.609211  0.902292  6.710229  0.112595  ... -1.167162  0.856642
# 1534  0.704803 -7.207626 -5.065417 -0.591209  ... -1.100492  1.679508
# 2086  0.829406  0.014989 -3.221514  1.980643  ...  0.039592 -0.785643
#
#             36        37        38        39        40        41        42  \
# ...

# %%
##############Your code here################
features, labels=None
pass

#################################################
# Out:
# (2100, 44)
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 2095    20
# 2096    20
# 2097    20
# 2098    20
# 2099    20
# Name: labels, Length: 2100, dtype: int64

# %% [markdown]
# # Chia du lieu thanh tap train va test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test,  y_train, y_test = train_test_split(features, labels, test_size=0.2)
print('Số lượng dữ liệu của tập huấn luyện: ', x_train.shape[0])
print('Số lượng dữ liệu của tập kiểm tra: ', x_test.shape[0])
# Out:
# Number of training data:  1680
# Number of testing data:  420

# %% [markdown]
# ## Xây dựng các bộ phân loại sử dụng sklearn

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

from sklearn.model_selection import GridSearchCV

# %%
###########Your code here###############





###########################################
# Out:
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                      weights='uniform')
# 0.9928571428571429

# %%
knn = KNeighborsClassifier()

# Parameter list for grid searching
param = {'n_neighbors': [1, 2, 3, 4, 5]}

# Initialize GridSearchCV object
gs = GridSearchCV(estimator=knn, param_grid=param, cv=4, n_jobs=4)
print(gs)

gs.fit(x_train, y_train)
gs.score(x_test, y_test)
# Out:
# GridSearchCV(cv=4, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=4,
#              param_grid={'n_neighbors': [1, 2, 3, 4, 5]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# 0.9928571428571429

# %%
gs.best_params_
# Out:
# {'n_neighbors': 1}

# %% [markdown]
# Thử lại

# %%
#############################Your code here##########################



###################################################################
# Out:
# 0.9833333333333333

# %% [markdown]
# # Decision Tree

# %%
dt = DecisionTreeClassifier()
print(dt)

dt.fit(x_train, y_train)
print(dt.score(x_train, y_train))
print(dt.score(x_test, y_test))
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
# 1.0
# 0.9928571428571429

# %%
#############################Your code here##########################



###################################################################
# Out:
# GridSearchCV(cv=4, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=4,
# ...

# %%
gs.best_params_
# Out:
# {'criterion': 'gini', 'min_samples_leaf': 1, 'splitter': 'best'}

# %% [markdown]
# # Thử lại với tham số tốt

# %%
#### YOUR CODE HERE ####


#### END YOUR CODE #####

# %% [markdown]
# ### Support Vector Machines
# Tương tự như KNN và Decision Tree, bạn hãy xây dựng bộ phân loại sử dụng SVM:

# %%
svm = SVC(C = 20)
print(svm)

svm.fit(x_train, y_train)
print(svm.score(x_train, y_train))
print(svm.score(x_test, y_test))
# Out:
# SVC(C=20, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# 0.9958333333333333
# 0.9952380952380953

# %%
svm = SVC()
param = {'C': [0.5, 1, 5, 20, 100, 500], 'kernel': ['poly', 'rbf', 'sigmoid']}

gs = GridSearchCV(estimator=svm, param_grid=param, cv=4, n_jobs=4)
print(gs)

gs.fit(x_train, y_train)
gs.score(x_test, y_test)
# Out:
# GridSearchCV(cv=4, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=4,
#              param_grid={'C': [0.5, 1, 5, 20, 100, 500],
#                          'kernel': ['poly', 'rbf', 'sigmoid']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# 0.9928571428571429

# %%
gs.best_params_
# Out:
# {'C': 100, 'kernel': 'rbf'}

# %% [markdown]
# Thử lại với tham số tốt

# %%
#### YOUR CODE HERE ####



#### END YOUR CODE #####
